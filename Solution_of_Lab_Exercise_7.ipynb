# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohankumar908/demo/blob/main/Solution_of_Lab_Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lab Exercise 7
# **Write a Python program to demonstrate how to draw a bar plot using Matplotlib**

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]

# Create the bar plot
plt.bar(categories, values)

# Add labels and title
plt.xlabel('Categories')  # Label for the x-axis
plt.ylabel('Values')      # Label for the y-axis
plt.title('Bar Plot Example')  # Title of the plot

# Show the plot
plt.show()

# %% [markdown]
# Syntax:
# ```
# plt.bar(x, height, width=0.8, bottom=None, align='center', color='blue', label=None)
# ```

# %% [markdown]
# ### **Question 1: Adding Legends**
# Modify the program to include a legend that describes what the bar plot represents (e.g., "Sample Data").
#
# Hint: Use plt.legend() to add a legend.

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]

# Create the bar plot
plt.bar(categories, values, label='Sample Data')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### **Question 2: Adding Labels to Bars**

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]

# Create the bar plot
bars = plt.bar(categories, values)

# Label each bar with its value using plt.bar_label()
plt.bar_label(bars)

plt.show()

# %% [markdown]
# ### **Question 3: Adding Color to the Bars**
# Modify the program to set different colors for each bar (e.g., use 'red', 'blue', 'green', 'yellow', 'purple').
#
# Hint: Pass a list of color strings to the color parameter in plt.bar().

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]

# Create the bar plot with custom colors
colors = ['red', 'blue', 'green', 'yellow', 'purple']
plot=plt.bar(categories, values, color=colors, label=values)
plt.legend()
plt.bar_label(plot)

# Show the plot
plt.show()

# %% [markdown]
# ### **Question 4: Changing the Width of the Bars**
# Update the program to change the width of the bars to 0.5 (default is 0.8).
#
# Hint: Use the width parameter in plt.bar() to set the bar width.

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]

# Create the bar plot with a custom bar width
plt.bar(categories, values, width=0.5)

# Show the plot
plt.show()

# %% [markdown]
# ### **Question 5: Horizontal bar plot**
# Modify the given bar plot code to create a horizontal bar plot instead of a vertical one.
#
# Hint: Use plt.barh() instead of plt.bar(). Remember to adjust the data so that the categories are on the y-axis and the values are on the x-axis.

# %%
import matplotlib.pyplot as plt

# Data for the horizontal bar plot
a=['P','Q','R','S','T']
b=[1,2,3,4,5]
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 6, 9]
colors = ['red', 'blue', 'green', 'yellow', 'purple']

# Create the horizontal bar plot
hor=plt.bar(a,b,width=0.4,color=colors,label=b,)
ver=plt.barh(categories, values,height=0.4,color=colors,label=values)
plt.legend()
plt.bar_label(hor)
plt.bar_label(ver)
plt.show()

# %%
import matplotlib.pyplot as plt

products= ['A', 'B', 'C', 'D', 'E']
jan=[120,150,180,90,75]
feb=[110,140,200,95,85]
months=['jan', 'feb']

month1=plt.bar(products,jan,align='center',width=0.4,label='jan')
month2=plt.bar(products,feb,align='edge',width=0.4,label='feb')
plt.xlabel('products')
plt.ylabel('sales')
plt.title('sales in two months')
plt.legend()
plt.bar_label(month1)
plt.bar_label(month2)

plt.show()
